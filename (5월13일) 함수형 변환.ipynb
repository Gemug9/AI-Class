# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt

# 데이터 다운로드
(train_data, train_labels), (test_data, test_labels) = tf.keras.datasets.imdb.load_data(num_words=1000)

# 원-핫 인코딩으로 변환하는 함수
def one_hot_sequences(sequences, dimension=1000):
    results = np.zeros((len(sequences), dimension))
    for i, word_index in enumerate(sequences):
        results[i, word_index] = 1.
    return results.astype('float32')  # 데이터 타입을 float32로 변환

# 데이터 크기 줄이기
train_data = one_hot_sequences(train_data, dimension=1000)
test_data = one_hot_sequences(test_data, dimension=1000)

# 신경망 모델 구축 (함수형 API)
inputs = tf.keras.Input(shape=(1000,))
x = tf.keras.layers.Dense(8, activation='relu')(inputs)
x = tf.keras.layers.Dense(8, activation='relu')(x)
outputs = tf.keras.layers.Dense(1, activation='sigmoid')(x)

model = tf.keras.Model(inputs=inputs, outputs=outputs)

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

# 신경망 훈련, 검증 데이터 전달
history = model.fit(train_data,
                    train_labels,
                    epochs=20,
                    batch_size=512,
                    validation_data=(test_data, test_labels),
                    verbose=2)

# 훈련 데이터의 손실값과 검증 데이터의 손실값을 그래프에 출력
history_dict = history.history
loss_values = history_dict['loss']      # 훈련 데이터 손실값
val_loss_values = history_dict['val_loss']  # 검증 데이터 손실값
acc = history_dict['accuracy']          # 정확도
epochs = range(1, len(acc) + 1)     # 에포크 수

plt.plot(epochs, loss_values, 'bo', label='Training loss')
plt.plot(epochs, val_loss_values, 'b', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()
# Out:
# Epoch 1/20
# 49/49 - 1s - loss: 0.6180 - accuracy: 0.6754 - val_loss: 0.4949 - val_accuracy: 0.7939 - 952ms/epoch - 19ms/step
# Epoch 2/20
# 49/49 - 0s - loss: 0.4153 - accuracy: 0.8283 - val_loss: 0.3733 - val_accuracy: 0.8443 - 172ms/epoch - 4ms/step
# Epoch 3/20
# 49/49 - 0s - loss: 0.3428 - accuracy: 0.8580 - val_loss: 0.3409 - val_accuracy: 0.8568 - 158ms/epoch - 3ms/step
# Epoch 4/20
# 49/49 - 0s - loss: 0.3197 - accuracy: 0.8685 - val_loss: 0.3336 - val_accuracy: 0.8592 - 153ms/epoch - 3ms/step
# Epoch 5/20
# 49/49 - 0s - loss: 0.3099 - accuracy: 0.8737 - val_loss: 0.3293 - val_accuracy: 0.8599 - 163ms/epoch - 3ms/step
# Epoch 6/20
# 49/49 - 0s - loss: 0.3046 - accuracy: 0.8756 - val_loss: 0.3314 - val_accuracy: 0.8593 - 175ms/epoch - 4ms/step
# Epoch 7/20
# 49/49 - 0s - loss: 0.3026 - accuracy: 0.8763 - val_loss: 0.3279 - val_accuracy: 0.8604 - 156ms/epoch - 3ms/step
# Epoch 8/20
# 49/49 - 0s - loss: 0.3025 - accuracy: 0.8738 - val_loss: 0.3291 - val_accuracy: 0.8608 - 167ms/epoch - 3ms/step
# Epoch 9/20
# 49/49 - 0s - loss: 0.2998 - accuracy: 0.8756 - val_loss: 0.3291 - val_accuracy: 0.8600 - 173ms/epoch - 4ms/step
# Epoch 10/20
# 49/49 - 0s - loss: 0.2978 - accuracy: 0.8779 - val_loss: 0.3299 - val_accuracy: 0.8598 - 171ms/epoch - 3ms/step
# Epoch 11/20
# 49/49 - 0s - loss: 0.2977 - accuracy: 0.8758 - val_loss: 0.3307 - val_accuracy: 0.8595 - 174ms/epoch - 4ms/step
# Epoch 12/20
# 49/49 - 0s - loss: 0.2971 - accuracy: 0.8776 - val_loss: 0.3307 - val_accuracy: 0.8586 - 171ms/epoch - 3ms/step
# Epoch 13/20
# 49/49 - 0s - loss: 0.2955 - accuracy: 0.8793 - val_loss: 0.3317 - val_accuracy: 0.8588 - 150ms/epoch - 3ms/step
# Epoch 14/20
# 49/49 - 0s - loss: 0.2937 - accuracy: 0.8806 - val_loss: 0.3335 - val_accuracy: 0.8588 - 173ms/epoch - 4ms/step
# Epoch 15/20
# 49/49 - 0s - loss: 0.2924 - accuracy: 0.8802 - val_loss: 0.3319 - val_accuracy: 0.8585 - 182ms/epoch - 4ms/step
# Epoch 16/20
# 49/49 - 0s - loss: 0.2897 - accuracy: 0.8819 - val_loss: 0.3327 - val_accuracy: 0.8590 - 174ms/epoch - 4ms/step
# Epoch 17/20
# 49/49 - 0s - loss: 0.2869 - accuracy: 0.8836 - val_loss: 0.3362 - val_accuracy: 0.8566 - 173ms/epoch - 4ms/step
# Epoch 18/20
# 49/49 - 0s - loss: 0.2844 - accuracy: 0.8827 - val_loss: 0.3370 - val_accuracy: 0.8576 - 157ms/epoch - 3ms/step
# Epoch 19/20
# 49/49 - 0s - loss: 0.2816 - accuracy: 0.8852 - val_loss: 0.3438 - val_accuracy: 0.8539 - 155ms/epoch - 3ms/step
# Epoch 20/20
# 49/49 - 0s - loss: 0.2807 - accuracy: 0.8847 - val_loss: 0.3395 - val_accuracy: 0.8556 - 181ms/epoch - 4ms/step
