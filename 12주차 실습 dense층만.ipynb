# %%
import numpy as np

import pandas as pd

import seaborn as sns

# %%
file_path = 'C:/Users/yoojm/Gachon/2학년 1학기/인공지능개론_이명규/Dataset/seeds_dataset.txt'


column_names = ["area ", "perimeter ", "compactness ", "length of kernel", "width of kernel", "asymmetry coefficient", "length of kernel groove", "class"]          

df = pd.read_csv(file_path, header=None, names=column_names, delimiter='\s+')

df.head(10)
# Out:
#    area   perimeter   compactness   length of kernel  width of kernel  \
# 0  15.26       14.84        0.8710             5.763            3.312
# 1  14.88       14.57        0.8811             5.554            3.333
# 2  14.29       14.09        0.9050             5.291            3.337
# 3  13.84       13.94        0.8955             5.324            3.379
# 4  16.14       14.99        0.9034             5.658            3.562
# 5  14.38       14.21        0.8951             5.386            3.312
# 6  14.69       14.49        0.8799             5.563            3.259
# 7  14.11       14.10        0.8911             5.420            3.302
# 8  16.63       15.46        0.8747             6.053            3.465
# 9  16.44       15.25        0.8880             5.884            3.505
#
#    asymmetry coefficient  length of kernel groove  class
# 0                  2.221                    5.220      1
# 1                  1.018                    4.956      1
# 2                  2.699                    4.825      1
# 3                  2.259                    4.805      1
# 4                  1.355                    5.175      1
# 5                  2.462                    4.956      1
# 6                  3.586                    5.219      1
# 7                  2.700                    5.000      1
# 8                  2.040                    5.877      1
# 9                  1.969                    5.533      1

# %%
# 결측치 확인
df.isnull().sum()
# Out:
# area                       0
# perimeter                  0
# compactness                0
# length of kernel           0
# width of kernel            0
# asymmetry coefficient      0
# length of kernel groove    0
# class                      0
# dtype: int64

# %%
# 레이블 갯수 확인 (그래프)
sns.countplot(data = df, x="class")
plt.ylabel("a")
plt.title("Label")
# Out:
# Text(0.5, 1.0, 'Label')

# %%
# 레이블 갯수 확인 (숫자)
df['class'].value_counts()
# Out:
# class
# 1    70
# 2    70
# 3    70
# Name: count, dtype: int64

# %%
# 박스 플롯 그리기

import seaborn as sns

import matplotlib.pyplot as plt

import pandas as pd
import matplotlib.pyplot as plt
from pandas.plotting import scatter_matrix

plt.figure(figsize=(20, 16))
for i, column in enumerate(df.columns):
    plt.subplot(3, 4, i+1)
    plt.boxplot(df[column])
    plt.title(column)

plt.tight_layout()
plt.show()

# %%
from sklearn.preprocessing import StandardScaler

# 표준화(Standardization)
scaler = StandardScaler()
scaled_data_standard = scaler.fit_transform(df.drop('class', axis=1))  # rings 열 제외하고 표준화
scaled_df_standard = pd.DataFrame(scaled_data_standard, columns=df.columns[:-1])  # 데이터프레임으로 변환
scaled_df_standard
# Out:
#         area   perimeter   compactness   length of kernel  width of kernel  \
# 0    0.142098    0.215462      0.000061          0.304218         0.141702
# 1    0.011188    0.008224      0.428515         -0.168625         0.197432
# 2   -0.192067   -0.360201      1.442383         -0.763637         0.208048
# 3   -0.347091   -0.475333      1.039381         -0.688978         0.319508
# 4    0.445257    0.330595      1.374509          0.066666         0.805159
# ..        ...         ...           ...               ...              ...
# 205 -0.915515   -1.043321      0.309736         -1.112048        -0.736716
# 206 -1.246235   -1.288937     -0.844122         -1.105261        -1.230328
# 207 -0.567571   -0.690247      0.733948         -0.888070        -0.070604
# 208 -1.036090   -1.035645     -0.801701         -1.026077        -1.121521
# 209 -0.877620   -0.935864     -0.110235         -0.872233        -0.755292
#
#      asymmetry coefficient  length of kernel groove
# 0                -0.986152                -0.383577
# 1                -1.788166                -0.922013
# 2                -0.667479                -1.189192
# 3                -0.960818                -1.229983
# 4                -1.563495                -0.475356
# ..                     ...                      ...
# 205              -0.046135                -1.097413
# 206               0.416540                -0.826156
# 207               3.076588                -0.718060
# 208              -0.068135                -0.742535
# 209               1.291223                -0.703784
#
# [210 rows x 7 columns]

# %%
x=scaled_df_standard

X = x.values

X
# Out:
# array([[ 1.42097769e-01,  2.15462437e-01,  6.06017918e-05, ...,
#          1.41701823e-01, -9.86151745e-01, -3.83577423e-01],
#        [ 1.11880257e-02,  8.22375713e-03,  4.28515270e-01, ...,
#          1.97432229e-01, -1.78816620e+00, -9.22013487e-01],
#        [-1.92066576e-01, -3.60200562e-01,  1.44238325e+00, ...,
#          2.08047544e-01, -6.67479334e-01, -1.18919199e+00],
#        ...,
#        [-5.67570840e-01, -6.90247348e-01,  7.33948301e-01, ...,
#         -7.06044846e-02,  3.07658816e+00, -7.18060432e-01],
#        [-1.03608992e+00, -1.03564515e+00, -8.01701104e-01, ...,
#         -1.12152071e+00, -6.81351965e-02, -7.42534799e-01],
#        [-8.77620233e-01, -9.35863561e-01, -1.10234659e-01, ...,
#         -7.55292327e-01,  1.29122264e+00, -7.03783718e-01]])

# %%
y = df['class']
# 원 핫 인코딩
Y = pd.get_dummies(y).values

Y
# Out:
# array([[ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [ True, False, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False,  True, False],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True],
#        [False, False,  True]])

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, Y,test_size=0.25,random_state=0)

print(X_train.shape, X_test.shape, y_train.shape, y_test.shape)
# Out:
# (157, 7) (53, 7) (157, 3) (53, 3)

# %%
import tensorflow as tf
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD,Adam

from tensorflow.keras.layers import Conv1D
from tensorflow.keras.layers import Input
from keras.layers import Dense, Flatten, Dropout

# %%
import tensorflow as tf

inputs = tf.keras.Input(shape=(7,))

x1 = tf.keras.layers.Flatten()(inputs)


x2 = tf.keras.layers.Dense(64, activation='relu')(x1) 


x3 = tf.keras.layers.Dense(32, activation='relu')(x2)


outputs = tf.keras.layers.Dense(3, activation='softmax')(x3)


model = tf.keras.Model(inputs=inputs, outputs=outputs)


model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])


model.summary()
# Out:
# WARNING:tensorflow:From C:\Users\yoojm\anaconda3\Lib\site-packages\keras\src\backend.py:1398: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# WARNING:tensorflow:From C:\Users\yoojm\anaconda3\Lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.
#
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 7)]               0
#
#  flatten (Flatten)           (None, 7)                 0
#
#  dense (Dense)               (None, 64)                512
#
#  dense_1 (Dense)             (None, 32)                2080
#
#  dense_2 (Dense)             (None, 3)                 99
#
# =================================================================
# Total params: 2691 (10.51 KB)
# Trainable params: 2691 (10.51 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
from keras.callbacks import EarlyStopping

early_stopping = EarlyStopping(patience=5)


model_history=model.fit(x=X_train, y=y_train, epochs=30, batch_size=32,validation_data= (X_test,y_test), callbacks = [early_stopping])
y_pred = model.predict(X_test)

y_test_class = np.argmax(y_test,axis=1)
y_pred_class = np.argmax(y_pred,axis=1)
# Out:
# Epoch 1/30
# WARNING:tensorflow:From C:\Users\yoojm\anaconda3\Lib\site-packages\keras\src\utils\tf_utils.py:492: The name tf.ragged.RaggedTensorValue is deprecated. Please use tf.compat.v1.ragged.RaggedTensorValue instead.
#
# WARNING:tensorflow:From C:\Users\yoojm\anaconda3\Lib\site-packages\keras\src\engine\base_layer_utils.py:384: The name tf.executing_eagerly_outside_functions is deprecated. Please use tf.compat.v1.executing_eagerly_outside_functions instead.
#
# 5/5 [==============================] - 1s 50ms/step - loss: 1.1760 - accuracy: 0.2484 - val_loss: 1.0405 - val_accuracy: 0.4528
# Epoch 2/30
# 5/5 [==============================] - 0s 11ms/step - loss: 1.0244 - accuracy: 0.5096 - val_loss: 0.9098 - val_accuracy: 0.8113
# Epoch 3/30
# 5/5 [==============================] - 0s 10ms/step - loss: 0.9005 - accuracy: 0.7834 - val_loss: 0.7983 - val_accuracy: 0.9245
# Epoch 4/30
# 5/5 [==============================] - 0s 10ms/step - loss: 0.7867 - accuracy: 0.8854 - val_loss: 0.7011 - val_accuracy: 0.9245
# Epoch 5/30
# 5/5 [==============================] - 0s 9ms/step - loss: 0.6927 - accuracy: 0.8726 - val_loss: 0.6173 - val_accuracy: 0.9245
# Epoch 6/30
# 5/5 [==============================] - 0s 9ms/step - loss: 0.6113 - accuracy: 0.8726 - val_loss: 0.5446 - val_accuracy: 0.8868
# Epoch 7/30
# 5/5 [==============================] - 0s 10ms/step - loss: 0.5408 - accuracy: 0.8854 - val_loss: 0.4829 - val_accuracy: 0.8868
# Epoch 8/30
# 5/5 [==============================] - 0s 10ms/step - loss: 0.4823 - accuracy: 0.8854 - val_loss: 0.4305 - val_accuracy: 0.8868
# Epoch 9/30
# 5/5 [==============================] - 0s 9ms/step - loss: 0.4345 - accuracy: 0.8917 - val_loss: 0.3865 - val_accuracy: 0.8868
# Epoch 10/30
# 5/5 [==============================] - 0s 9ms/step - loss: 0.3930 - accuracy: 0.8981 - val_loss: 0.3500 - val_accuracy: 0.8868
# Epoch 11/30
# 5/5 [==============================] - 0s 9ms/step - loss: 0.3589 - accuracy: 0.9045 - val_loss: 0.3196 - val_accuracy: 0.8868
# Epoch 12/30
# 5/5 [==============================] - 0s 9ms/step - loss: 0.3303 - accuracy: 0.8981 - val_loss: 0.2948 - val_accuracy: 0.8868
# Epoch 13/30
# 5/5 [==============================] - 0s 9ms/step - loss: 0.3056 - accuracy: 0.9172 - val_loss: 0.2767 - val_accuracy: 0.9057
# Epoch 14/30
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2866 - accuracy: 0.9236 - val_loss: 0.2616 - val_accuracy: 0.9057
# Epoch 15/30
# 5/5 [==============================] - 0s 8ms/step - loss: 0.2678 - accuracy: 0.9236 - val_loss: 0.2517 - val_accuracy: 0.9057
# Epoch 16/30
# 5/5 [==============================] - 0s 10ms/step - loss: 0.2526 - accuracy: 0.9236 - val_loss: 0.2438 - val_accuracy: 0.9057
# Epoch 17/30
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2404 - accuracy: 0.9236 - val_loss: 0.2384 - val_accuracy: 0.9245
# Epoch 18/30
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2284 - accuracy: 0.9236 - val_loss: 0.2335 - val_accuracy: 0.9245
# Epoch 19/30
# 5/5 [==============================] - 0s 9ms/step - loss: 0.2190 - accuracy: 0.9236 - val_loss: 0.2277 - val_accuracy: 0.9245
# Epoch 20/30
# 5/5 [==============================] - 0s 10ms/step - loss: 0.2102 - accuracy: 0.9236 - val_loss: 0.2250 - val_accuracy: 0.9245
# Epoch 21/30
# 5/5 [==============================] - 0s 10ms/step - loss: 0.2028 - accuracy: 0.9236 - val_loss: 0.2226 - val_accuracy: 0.9245
# Epoch 22/30
# 5/5 [==============================] - 0s 8ms/step - loss: 0.1953 - accuracy: 0.9236 - val_loss: 0.2184 - val_accuracy: 0.9245
# Epoch 23/30
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1890 - accuracy: 0.9236 - val_loss: 0.2176 - val_accuracy: 0.9245
# Epoch 24/30
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1831 - accuracy: 0.9299 - val_loss: 0.2143 - val_accuracy: 0.9245
# Epoch 25/30
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1770 - accuracy: 0.9299 - val_loss: 0.2136 - val_accuracy: 0.9245
# Epoch 26/30
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1721 - accuracy: 0.9427 - val_loss: 0.2123 - val_accuracy: 0.9245
# Epoch 27/30
# 5/5 [==============================] - 0s 10ms/step - loss: 0.1674 - accuracy: 0.9427 - val_loss: 0.2134 - val_accuracy: 0.9245
# Epoch 28/30
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1623 - accuracy: 0.9490 - val_loss: 0.2108 - val_accuracy: 0.9245
# Epoch 29/30
# 5/5 [==============================] - 0s 9ms/step - loss: 0.1584 - accuracy: 0.9490 - val_loss: 0.2109 - val_accuracy: 0.9245
# Epoch 30/30
# 5/5 [==============================] - 0s 11ms/step - loss: 0.1557 - accuracy: 0.9490 - val_loss: 0.2075 - val_accuracy: 0.9434
# 2/2 [==============================] - 0s 3ms/step

# %%
import matplotlib.pyplot as plt
import seaborn as sns

loss =model_history.history['loss']
val_loss =model_history.history['val_loss']
epochs = range(1, len(loss) + 1)
plt.plot(epochs, loss, 'y', label='Training loss')
plt.plot(epochs, val_loss, 'r', label='Validation loss')
plt.title('Training and validation loss')
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.legend()
plt.show()

# %%
#Accuracy of the predicted values
from sklearn.metrics import classification_report,confusion_matrix
print(classification_report(y_test_class,y_pred_class))
print(confusion_matrix(y_test_class,y_pred_class))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.94      0.91        17
#            1       1.00      0.90      0.95        21
#            2       0.94      1.00      0.97        15
#
#     accuracy                           0.94        53
#    macro avg       0.94      0.95      0.94        53
# weighted avg       0.95      0.94      0.94        53
#
# [[16  0  1]
#  [ 2 19  0]
#  [ 0  0 15]]
